# %% [markdown]
# ## Python Project - Prosper Loan
# ## by Ifeoluwa Kehinde
#
# ## Introduction
#
# This dataset is a csv file of loan recipients which contains 113,937 rows and 81 columns. It includes strings, integers, floats and the boolean variables. My objective is to generate insight by visualizing some of the key measures that would shape and foster data-driven decision for the business.
# The prosper loan dataset will be given the variable df for the purpose of this analysis.

# %% [markdown]
# ### Preliminary Wrangling

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('prosper loan.csv')

# %%
df.columns = df.columns.str.lower()

# %%
df.shape
# Out:
# (113937, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   listingkey                           113937 non-null  object
#  1   listingnumber                        113937 non-null  int64
#  2   listingcreationdate                  113937 non-null  object
#  3   creditgrade                          28953 non-null   object
#  4   term                                 113937 non-null  int64
#  5   loanstatus                           113937 non-null  object
#  6   closeddate                           55089 non-null   object
#  7   borrowerapr                          113912 non-null  float64
#  8   borrowerrate                         113937 non-null  float64
#  9   lenderyield                          113937 non-null  float64
# ...

# %% [markdown]
# ## Data structure
#
# Some of the main features of interest in df include the loan term, loan status, credit grade, occupation, employement status, monthly loan payments, loan interests and fees amongst many others.
#
# A loan term has a great impact on the ability to pay back. In this analysis, the loan term would show the distribution of the term or duration the recipients will take to pay up their loans. It will also give an insight into the category preference of the loan terms and influence decisions around it.
#
# The loan status would provide insights as to loan performance in terms of completed loans, runing loans, and past due loans. Insights would be generated on the measure of compliant loan takers who repay their loans and loan defaulters. Such insight can help to demarcate these defaulters such that prosper loan remain in business.
#
# A poor credit history indicates an increased risk of default. The credit grade distribution would provide insights into the credit score of the recipients based on the borrower’s credit history and repayment risk.
#
# The occupation would show the distribution of borrowers occupation and can influence the quality and type of borrowers that prosper loan may want to do business with going forward.
#
# The employemnt status would also provide insights to the status of employment of borrowers.

# %% [markdown]
# ## Univariate variables:
#
# In this analysis, the follwoing univariate variables would be analyzed to derieve insights on the performance of prosper loan business.
#
# 1. Loan term distribution
# 2. Loan status distribution
# 3. Credit grade distribution
# 4. Occupation
# 5. Employment status

# %%
sns.countplot(data = df, x='term',color='Red');
plt.title('Loan Term Distribution');
ax = sns.countplot(x='term', data=df,color='Red')
ax.bar_label(ax.containers[0], fmt='%d',fontsize=9,fontweight='light');

# %%
sns.countplot(data = df, x='loanstatus',color='Red');
plt.title('Loan Status Distribution');
fig = plt.gcf()
plt.xticks(rotation=60);
fig.set_size_inches(10, 5)
ax = sns.countplot(x='loanstatus', data=df,color='Red')
ax.bar_label(ax.containers[0], fmt='%d',fontsize=9,fontweight='light');

# %%
sns.countplot(data = df, x='creditgrade',color='Red');
plt.title('Credit Grade Distribution');
fig = plt.gcf()
fig.set_size_inches(10, 5)

# %%
sns.countplot(data = df, x='occupation',color='Red');
plt.title('Occupation Distribution');
fig = plt.gcf()
plt.xticks(rotation=90);
fig.set_size_inches(12, 6)

# %%
sns.countplot(data=df, x='employmentstatus', color='Red');
plt.title('Employment Status');
fig = plt.gcf()
fig.set_size_inches(10, 5)
ax = sns.countplot(x='employmentstatus', data=df,color='Red')
ax.bar_label(ax.containers[0], fmt='%d',fontsize=9,fontweight='light');

# %%
sns.displot(df.loanoriginalamount, color='red');
plt.title('Loan Original Amount Distribution')
fig = plt.gcf()
fig.set_size_inches(10, 6)

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest?
#
# 1. Loan term distribution: The chart showed a majority of proper loan borrowers subcribed to the 36 term period.
#
# 2. Loan status distribution: The current borrowers topped the chart with over 56,000 borrowers next to the 38,000 who have completed their loans. The defaulter category was distributed between 1- 120 days of past due date.
#
# 3. Credit grade distribution: The C and D credit grade topped the chart as the quality score of prosper loan borrowers based on their credit history, quality of the collateral, and repayment risk.
#
# 4. The occupation distribution: The chart showed the various occupations of the borrowers of prosper loans.
#
# 5. Employment distribution: The chart was explicit and showed a majority of over 60,000 proper loan borrowers are employed.

# %% [markdown]
# ## Bivariate Variables
#
# In this analysis, the follwoing bivariate variables would be analyzed to derieve insights in the performance of prosper loan.
#
# 1. Recommendation by count of investment from friends: This would show the relationship between recommendation and investment made.
#
# 2. Loan status by interest rate: This will show the distribution of the 5 number summary; the minimum, first quartile, second quartile, median, third quartile and the maximum of the interest rates on the loan status.
#
# 3. Borrower APR by employemnt status: This will provide insight into the annual percentage rate paid by the categories of employment.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   listingkey                           113937 non-null  object
#  1   listingnumber                        113937 non-null  int64
#  2   listingcreationdate                  113937 non-null  object
#  3   creditgrade                          28953 non-null   object
#  4   term                                 113937 non-null  int64
#  5   loanstatus                           113937 non-null  object
#  6   closeddate                           55089 non-null   object
#  7   borrowerapr                          113912 non-null  float64
#  8   borrowerrate                         113937 non-null  float64
#  9   lenderyield                          113937 non-null  float64
# ...

# %%
sns.regplot(data=df, x='recommendations', y='investmentfromfriendscount', color= 'Red')
plt.title('Recommendation by Investment from friends')
fig = plt.gcf()
fig.set_size_inches(10, 6)

# %%
sns.boxplot(data=df, x='loanstatus', y='borrowerrate', color= 'Red')
plt.xlabel('Loan Status')
plt.ylabel('Interest Rate')
plt.title('Loan Status by Interest Rate')
plt.xticks(rotation=60)
fig.set_size_inches(12, 6)
plt.show()

# %%
sns.boxplot(data=df,y='borrowerapr',x='employmentstatus', color = 'Red');
plt.title('BorrowerAPR by Employment Status');
plt.ylabel('Borrower APR',size=10);
plt.xlabel('Employment Status',size=10);
fig.set_size_inches(10, 6)
plt.xticks(rotation=60);

# %%
sns.regplot(data=df,x='monthlyloanpayment', y='lp_interestandfees', color = 'Red');
plt.title('Monthly loan payment by LP_interest and fees');

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest?
#
# 1. Recommendation by count of investment from friends: The result showed a positive relationship that establishes an increase in investment from friends who made recommendations.
#
# 2. Loan status by interest rate: The chart showed the different distribution of loan status by interest rate having normal distributions and left skewed distributions. The normal distribution indicating the mean = median = mode while the left skewed distribution indicating the presence of outliers.
#
# 3. Borrower APR by employemnt status: This also showed the different distribution of Borrower annual percentage rate by their employment status having normal distributions, left skewed distributions, and right skewed distributions. The normal distribution indicating the mean = median = mode while the left and right skewed distribution indicating the presence of outliers in the dataset.

# %% [markdown]
# ### Observations and Conclusion
#
# The dataset highlights the interplay between various features in the dataset and how they can influence loan outcomes, borrowing preferences, and the cost of borrowing. Further analysis and exploration of these relationships can provide deeper insights into the factors affecting loan status, interest rates, loan terms, and borrower characteristics.
